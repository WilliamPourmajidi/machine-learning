# %% [markdown]
# # Module 9 – Build a CNN Step by Step (Keras + MNIST)
#
# A hands-on walkthrough inspired by the Medium guide. Run cells in order, read the notes, and tweak the model.
#
# **You will practice:**
# - Loading and inspecting MNIST digits
# - Preparing images for a CNN (scaling, channel dimension, one-hot labels)
# - Stacking `Conv2D` + `MaxPooling2D` layers in Keras
# - Training, evaluating, and plotting results
# - Running small experiments to improve the baseline
#
# **Setup:** install `tensorflow` and `matplotlib` (e.g., `pip install tensorflow matplotlib`).

# %% [markdown]
# ## 1. Imports and reproducibility
# Keep dependencies minimal and set seeds so runs stay comparable. GPU runs may still vary slightly.

# %%
        import os
        import random
        import numpy as np
        import matplotlib.pyplot as plt
        import tensorflow as tf
        
        # Reproducibility (CPU is most deterministic)
        seed = 42
        random.seed(seed)
        np.random.seed(seed)
        tf.random.set_seed(seed)
        os.environ['PYTHONHASHSEED'] = str(seed)
        
        print('TensorFlow version:', tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       2 import random
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 import tensorflow as tf
#       7 # Reproducibility (CPU is most deterministic)
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/matplotlib/__init__.py:997
#     992     _log.debug('loaded rc file %s', fname)
#     994     return config
# --> 997 rcParamsDefault = _rc_params_in_file(
#     998     cbook._get_data_path("matplotlibrc"),
#     999     # Strip leading comment.
#    1000     transform=lambda line: line[1:] if line.startswith("#") else line,
#    1001     fail_on_error=True)
#    1002 rcParamsDefault._update_raw(rcsetup._hardcoded_defaults)
#    1003 rcParamsDefault._ensure_has_backend()
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/matplotlib/__init__.py:934, in _rc_params_in_file(fname, transform, fail_on_error)
#     932 if key in rcsetup._validators:
#     933     if fail_on_error:
# --> 934         config[key] = val  # try to convert to proper type or raise
#     935     else:
#     936         try:
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/matplotlib/__init__.py:769, in RcParams.__setitem__(self, key, val)
#     767             return
#     768 try:
# --> 769     cval = self.validate[key](val)
#     770 except ValueError as ve:
#     771     raise ValueError(f"Key {key}: {ve}") from None
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/matplotlib/rcsetup.py:342, in validate_color(s)
#     339         if is_color_like(stmp):
#     340             return stmp
# --> 342 if is_color_like(s):
#     343     return s
#     345 # If it is still valid, it must be a tuple (as a string from matplotlibrc).
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/matplotlib/colors.py:229, in is_color_like(c)
#     227     return True
#     228 try:
# --> 229     to_rgba(c)
#     230 except (TypeError, ValueError):
#     231     return False
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/matplotlib/colors.py:316, in to_rgba(c, alpha)
#     314     rgba = None
#     315 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 316     rgba = _to_rgba_no_colorcycle(c, alpha)
#     317     try:
#     318         _colors_full_map.cache[c, alpha] = rgba
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/matplotlib/colors.py:338, in _to_rgba_no_colorcycle(c, alpha)
#     336     raise ValueError("'alpha' must be between 0 and 1, inclusive")
#     337 orig_c = c
# --> 338 if c is np.ma.masked:
#     339     return (0., 0., 0., 0.)
#     340 if isinstance(c, str):
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/numpy/__init__.py:343, in __getattr__(attr)
#     336 def __dir__():
#     337     public_symbols = globals().keys() | {'testing'}
#     338     public_symbols -= {
#     339         "core", "matrixlib",
#     340         # These were moved in 1.25 and may be deprecated eventually:
#     341         "ModuleDeprecationWarning", "VisibleDeprecationWarning",
#     342         "ComplexWarning", "TooHardError", "AxisError"
# --> 343     }
#     344     return list(public_symbols)
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/numpy/ma/__init__.py:42
#       1 """
#       2 =============
#       3 Masked Arrays
#    (...)
#      40
#      41 """
# ---> 42 from . import core
#      43 from .core import *
#      45 from . import extras
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/numpy/ma/core.py:37
#      35 from numpy import ndarray, amax, amin, iscomplexobj, bool_, _NoValue
#      36 from numpy import array as narray
# ---> 37 from numpy.lib.function_base import angle
#      38 from numpy.compat import (
#      39     getargspec, formatargspec, long, unicode, bytes
#      40     )
#      41 from numpy import expand_dims
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/numpy/lib/function_base.py:25
#      23 from numpy.core import overrides
#      24 from numpy.core.function_base import add_newdoc
# ---> 25 from numpy.lib.twodim_base import diag
#      26 from numpy.core.multiarray import (
#      27     _place, add_docstring, bincount, normalize_axis_index, _monotonicity,
#      28     interp as compiled_interp, interp_complex as compiled_interp_complex
#      29     )
#      30 from numpy.core.umath import _add_newdoc_ufunc as add_newdoc_ufunc
#
# File /opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/numpy/lib/twodim_base.py:15
#      13 from numpy.core import overrides
#      14 from numpy.core import iinfo
# ---> 15 from numpy.lib.stride_tricks import broadcast_to
#      18 __all__ = [
#      19     'diag', 'diagflat', 'eye', 'fliplr', 'flipud', 'tri', 'triu',
#      20     'tril', 'vander', 'histogram2d', 'mask_indices', 'tril_indices',
#      21     'tril_indices_from', 'triu_indices', 'triu_indices_from', ]
#      24 array_function_dispatch = functools.partial(
#      25     overrides.array_function_dispatch, module='numpy')
#
# ImportError: cannot import name 'broadcast_to' from 'numpy.lib.stride_tricks' (/opt/anaconda3/envs/smiledetection/lib/python3.10/site-packages/numpy/lib/stride_tricks.py)

# %% [markdown]
# ## 2. Load MNIST digits
# MNIST has 70k 28x28 grayscale images of handwritten digits. Keras fetches and caches it for us.

# %%
        # Keras gives train and test splits out of the box
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
        
        print('Training set:', x_train.shape, 'Labels:', y_train.shape)
        print('Test set     :', x_test.shape, 'Labels:', y_test.shape)

# %% [markdown]
# ## 3. Peek at a few images
# Always look at the raw data first to ground the rest of the pipeline.

# %%
        def show_examples(images, labels, n=6):
            plt.figure(figsize=(10, 2))
            for i in range(n):
                plt.subplot(1, n, i + 1)
                plt.imshow(images[i], cmap='gray')
                plt.axis('off')
                plt.title(int(labels[i]))
            plt.show()
        
        show_examples(x_train, y_train)

# %% [markdown]
# ## 4. Preprocess: scale, reshape, one-hot labels
# - CNNs expect channels, so reshape from `(28, 28)` to `(28, 28, 1)`.
# - Scale pixels to `[0, 1]` for stable gradients.
# - Convert labels to one-hot vectors to match a `softmax` output.

# %%
        x_train = (x_train.astype('float32') / 255.0)[..., None]
        x_test = (x_test.astype('float32') / 255.0)[..., None]
        
        num_classes = 10
        y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes)
        y_test_cat = tf.keras.utils.to_categorical(y_test, num_classes)
        
        print('New train shape:', x_train.shape)
        print('Example label vector:', y_train_cat[0])

# %% [markdown]
# ## 5. Build the CNN
# Start with a small, readable architecture:
# - `Conv2D` layers learn local patterns; `ReLU` activates them.
# - `MaxPooling2D` downsamples while keeping strongest signals.
# - `Dropout` regularizes; `Dense` + `softmax` maps to 10 classes.

# %%
        model = tf.keras.Sequential([
            tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(num_classes, activation='softmax')
        ])
        
        model.summary()

# %% [markdown]
# ## 6. Compile the model
# - Optimizer: Adam (adaptive learning rate)
# - Loss: `sparse_categorical_crossentropy` fits integer labels
# - Metric: accuracy keeps feedback simple

# %%
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

# %% [markdown]
# ## 7. Train
# Five epochs are fast on CPU and good for a first pass. Validation uses the test set for quick feedback.

# %%
        history = model.fit(
            x_train, y_train,
            epochs=5,
            batch_size=128,
            validation_data=(x_test, y_test),
            verbose=2
        )

# %% [markdown]
# ## 8. Evaluate and plot learning curves
# Check test accuracy, then look at loss/accuracy over epochs to spot under- or overfitting.

# %%
        test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
        print(f"Test accuracy: {test_acc:.4f} | Test loss: {test_loss:.4f}")
        
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
        ax1.plot(history.history['loss'], label='train')
        ax1.plot(history.history['val_loss'], label='val')
        ax1.set_title('Loss')
        ax1.legend()
        
        ax2.plot(history.history['accuracy'], label='train')
        ax2.plot(history.history['val_accuracy'], label='val')
        ax2.set_title('Accuracy')
        ax2.legend()
        plt.show()

# %% [markdown]
# ## 9. Predict on new images
# Turn model outputs into class IDs with `argmax`, then visualize a few predictions next to the digits.

# %%
        num_samples = 8
        sample_images = x_test[:num_samples]
        sample_labels = y_test[:num_samples]
        preds = model.predict(sample_images)
        pred_classes = preds.argmax(axis=1)
        
        show_examples(sample_images.squeeze(-1), pred_classes, n=num_samples)
        print('True labels:', sample_labels.tolist())
        print('Predicted   :', pred_classes.tolist())

# %% [markdown]
# ## 10. Try your own experiments
# - Train longer (`epochs=10`+) or with a smaller `batch_size`.
# - Add `BatchNormalization` after convolutions.
# - Replace pooling with `Conv2D` stride 2 to keep learning features while downsampling.
# - Add data augmentation: `RandomFlip`, `RandomRotation`, `RandomZoom`.
# - Swap in `tf.keras.datasets.cifar10` (RGB, shape `(32, 32, 3)`) and adjust the model.
