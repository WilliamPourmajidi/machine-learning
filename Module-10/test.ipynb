# %%
import pandas as pd

# Load CSV file into a DataFrame
# Replace 'your_file.csv' with the actual path to your file
df = pd.read_csv('your_file.csv')

# Preview the first 5 rows
print(df.head())

# Basic info: column names, data types, and non-null counts
print(df.info())

# Summary statistics for numeric columns
print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load CSV file into a DataFrame
#       2 # Replace 'your_file.csv' with the actual path to your file
# ----> 3 df = pd.read_csv('your_file.csv')
#       5 # Preview the first 5 rows
#       6 print(df.head())
#
# NameError: name 'pd' is not defined
